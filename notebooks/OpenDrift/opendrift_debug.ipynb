# %%
import xarray as xr
import netCDF4 as nc
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.parser import parse
from glob import glob
from IPython.display import HTML
import os
from opendrift.readers import reader_ROMS_native, reader_netCDF_CF_unstructured
from opendrift.models.oceandrift import OceanDrift
from salishsea_tools import viz_tools

plt.rcParams['animation.html'] = 'html5'
# %matplotlib inline

# %% [markdown]
# ## SSC

# %%
# Define paths
paths = {
    'NEMO': '/results/SalishSea/hindcast.201812',
    'NEMO_cutoff': '/results2/SalishSea/hindcast.201812_annex',
    'HRDPS': '/results/forcing/atmospheric/GEM2.5/operational',
    'out': '/data/bmoorema/results/opendrift',
    'date_cutoff': '2016 Nov 21',
}
mask = xr.open_dataset('/data/bmoorema/MEOPAR/grid/mesh_mask201702.nc')
daterange = [parse(d) for d in ['2017 Nov 10 00:00', '2017 Nov 12 00:00']]

# %%
datestr = daterange[0].strftime('%Y%m')
filenames = sorted(glob(os.path.join(paths['out'], 'forcing', f'SalishSea_1h_{datestr}*')))
o = OceanDrift(loglevel=20)
o.add_readers_from_list(filenames, lazy=False)
o.seed_elements(-123.3, 49.1, radius=500, number=500, time=daterange[0])
o.set_config('general:use_basemap_landmask', True)
o.run(end_time=daterange[1], time_step=1800)
# Out:
# 22:05:53 INFO: OpenDriftSimulation initialised (version 1.0.6)
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171110_20171110_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171111_20171111_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171112_20171112_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171113_20171113_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171114_20171114_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171115_20171115_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171116_20171116_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171117_20171117_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171118_20171118_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:53 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171119_20171119_opendrift.nc
# 22:05:53 INFO: Opening file with Dataset
# 22:05:54 INFO: Opening dataset: /data/bmoorema/results/opendrift/forcing/SalishSea_1h_20171120_20171120_opendrift.nc
# 22:05:54 INFO: Opening file with Dataset
# 22:05:54 INFO: Config validation OK
# 22:05:54 INFO: Fallback values will be used for the following variables which have no readers:
# 22:05:54 INFO: 	x_wind: 0.000000
# 22:05:54 INFO: 	y_wind: 0.000000
# 22:05:54 INFO: Adding a dynamical landmask (resolution "h") based on assumed maximum speed of 1 m/s. Adding a customised landmask may be faster...
# 22:05:54 INFO: No display found. Using non-interactive Agg backend
# 22:06:01 INFO: Using existing reader for land_binary_mask
# 22:06:01 INFO: All points are in ocean
# 22:06:01 INFO: 2017-11-10 00:00:00 - step 1 of 96 - 500 active elements (0 deactivated)
# 22:06:01 INFO: 2017-11-10 00:30:00 - step 2 of 96 - 500 active elements (0 deactivated)
# 22:06:03 INFO: 2017-11-10 01:00:00 - step 3 of 96 - 500 active elements (0 deactivated)
# 22:06:05 INFO: 2017-11-10 01:30:00 - step 4 of 96 - 500 active elements (0 deactivated)
# 22:06:05 INFO: 2017-11-10 02:00:00 - step 5 of 96 - 500 active elements (0 deactivated)
# 22:06:06 INFO: 2017-11-10 02:30:00 - step 6 of 96 - 500 active elements (0 deactivated)
# 22:06:06 INFO: 2017-11-10 03:00:00 - step 7 of 96 - 500 active elements (0 deactivated)
# 22:06:08 INFO: 2017-11-10 03:30:00 - step 8 of 96 - 500 active elements (0 deactivated)
# 22:06:08 INFO: 2017-11-10 04:00:00 - step 9 of 96 - 500 active elements (0 deactivated)
# 22:06:10 INFO: 2017-11-10 04:30:00 - step 10 of 96 - 500 active elements (0 deactivated)
# 22:06:10 INFO: 2017-11-10 05:00:00 - step 11 of 96 - 500 active elements (0 deactivated)
# 22:06:12 INFO: 2017-11-10 05:30:00 - step 12 of 96 - 500 active elements (0 deactivated)
# 22:06:12 INFO: 2017-11-10 06:00:00 - step 13 of 96 - 500 active elements (0 deactivated)
# 22:06:14 INFO: 2017-11-10 06:30:00 - step 14 of 96 - 500 active elements (0 deactivated)
# 22:06:14 INFO: 2017-11-10 07:00:00 - step 15 of 96 - 500 active elements (0 deactivated)
# 22:06:16 INFO: 2017-11-10 07:30:00 - step 16 of 96 - 500 active elements (0 deactivated)
# 22:06:16 INFO: 2017-11-10 08:00:00 - step 17 of 96 - 500 active elements (0 deactivated)
# 22:06:18 INFO: 2017-11-10 08:30:00 - step 18 of 96 - 500 active elements (0 deactivated)
# 22:06:18 INFO: 2017-11-10 09:00:00 - step 19 of 96 - 500 active elements (0 deactivated)
# 22:06:19 INFO: 2017-11-10 09:30:00 - step 20 of 96 - 500 active elements (0 deactivated)
# 22:07:11 INFO: 2017-11-11 14:00:00 - step 77 of 96 - 500 active elements (0 deactivated)
# 22:07:12 INFO: 2017-11-11 14:30:00 - step 78 of 96 - 500 active elements (0 deactivated)
# 22:07:12 INFO: 2017-11-11 15:00:00 - step 79 of 96 - 500 active elements (0 deactivated)
# 22:07:14 INFO: 2017-11-11 15:30:00 - step 80 of 96 - 500 active elements (0 deactivated)
# 22:07:14 INFO: 2017-11-11 16:00:00 - step 81 of 96 - 500 active elements (0 deactivated)
# 22:07:16 INFO: 2017-11-11 16:30:00 - step 82 of 96 - 500 active elements (0 deactivated)
# 22:07:16 INFO: 2017-11-11 17:00:00 - step 83 of 96 - 500 active elements (0 deactivated)
# 22:07:18 INFO: 2017-11-11 17:30:00 - step 84 of 96 - 500 active elements (0 deactivated)
# 22:07:18 INFO: 2017-11-11 18:00:00 - step 85 of 96 - 500 active elements (0 deactivated)
# 22:07:20 INFO: 2017-11-11 18:30:00 - step 86 of 96 - 500 active elements (0 deactivated)
# 22:07:20 INFO: 2017-11-11 19:00:00 - step 87 of 96 - 500 active elements (0 deactivated)
# 22:07:22 INFO: 2017-11-11 19:30:00 - step 88 of 96 - 500 active elements (0 deactivated)
# 22:07:22 INFO: 2017-11-11 20:00:00 - step 89 of 96 - 500 active elements (0 deactivated)
# 22:07:24 INFO: 2017-11-11 20:30:00 - step 90 of 96 - 500 active elements (0 deactivated)
# 22:07:24 INFO: 2017-11-11 21:00:00 - step 91 of 96 - 500 active elements (0 deactivated)
# 22:07:25 INFO: 2017-11-11 21:30:00 - step 92 of 96 - 500 active elements (0 deactivated)
# 22:07:25 INFO: 2017-11-11 22:00:00 - step 93 of 96 - 500 active elements (0 deactivated)
# 22:07:27 INFO: 2017-11-11 22:30:00 - step 94 of 96 - 500 active elements (0 deactivated)
# 22:07:27 INFO: 2017-11-11 23:00:00 - step 95 of 96 - 500 active elements (0 deactivated)
# 22:07:29 INFO: 2017-11-11 23:30:00 - step 96 of 96 - 500 active elements (0 deactivated)
# 22:07:29 INFO: Zooming basemap to (-123.99746551513672 to -122.88153991699218 E), (48.8863037109375 to 49.5558578491211 N)

# %%
# %%capture
anim = o.animation()

# %%
HTML(anim.to_html5_video())
# Out:
# 22:07:34 INFO: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 22:07:34 INFO: figure size (inches) has been adjusted from 9.995014956025413 x 10.0 to 9.972222222222221 x 10.0
# 22:07:34 INFO: MovieWriter.run: running command: ['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '718x720', '-pix_fmt', 'rgba', '-r', '20.0', '-loglevel', 'quiet', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmp6w01r64a/temp.m4v']
# <video width="718" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
